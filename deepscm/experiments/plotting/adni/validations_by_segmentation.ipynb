# %%
ROOT_PATH = '../../../../'
UKBB_DATA_PATH = ROOT_PATH + 'assets/data/ukbb/'
BASE_LOG_PATH = ROOT_PATH + 'assets/models/ukbb/SVIExperiment'

import sys
import os

sys.path.append(ROOT_PATH)

os.environ['CUDA_VISIBLE_DEVICES'] = ''

import torch
import pyro
import numpy as np
import PIL as pl
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import pandas as pd
import inspect
from collections import OrderedDict
from collections import defaultdict
from functools import partial
from IPython.display import display, Image # to display images
from sklearn import cluster # for running K-means
from skimage.io import imread
import torch
from PIL import Image

from tqdm import tqdm, trange

import traceback
import warnings
from scipy.stats import gaussian_kde

warnings.filterwarnings("ignore", category=UserWarning)

torch.autograd.set_grad_enabled(False);

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

from matplotlib.colors import ListedColormap
from matplotlib import cm
cmaps = [cm.Reds, cm.Blues, cm.Greens]
img_cm = 'Greys_r'
diff_cm = 'seismic'

from deepscm.datasets.medical.adni import ADNIDataset

data_dir = '/home/aay993/full_imputed_clinical_covariates.csv' # standard data path 
base_path = '/home/aay993/bias_corrected_registered_slices/' # standard img path 

# data_dir = '/home/aay993/val_patients_clinical_covariates.csv' # validation data path 
# base_path = '/home/aay993/validation_brains/slices' # validation img path 
downsample = 3
ukbb_test = ADNIDataset(data_dir, base_path=base_path, crop_type='center', downsample=downsample)

# %%
from deepscm.experiments.medical import ukbb  # noqa: F401
from deepscm.experiments.medical.base_experiment_adni import EXPERIMENT_REGISTRY, MODEL_REGISTRY

var_name = {'ventricle_volume': 'v', 
'brain_volume': 'b', 
'sex': 's', 'age': 'a',
'tau': 't', 'education': 'e', 'moca': 'm', 'av45': 'av'}
value_fmt = {
    'ventricle_volume': lambda s: rf'{float(s)/1000:.4g}\,\mathrm{{ml}}',
    'brain_volume': lambda s: rf'{float(s)/1000:.4g}\,\mathrm{{ml}}',
    'age': lambda s: rf'{int(s):d}\,\mathrm{{y}}',
    'sex': lambda s: '{}'.format(['\mathrm{male}', '\mathrm{female}'][int(s)]),
    'tau': lambda s: rf'{float(s):.4}\,\mathrm{{pg/ml}}',
    'education': lambda s: rf'{int(s):d}\,\mathrm{{u}}',
    'moca': lambda s: rf'{int(s):d}\,\mathrm{{score}}',
    'av45': lambda s: rf'{float(s):.4}\,\mathrm{{mSUVR}}',
}

def fmt_intervention(intervention):
    if isinstance(intervention, str):
        var, value = intervention[3:-1].split('=')
        return f"$do({var_name[var]}={value_fmt[var](value)})$"
    else:
        all_interventions = ',\n'.join([f'${var_name[k]}={value_fmt[k](v)}$' for k, v in intervention.items()])
        return f"do({all_interventions})"

def prep_data(batch):
    x = 255. * batch['x'].float().unsqueeze(0)
    age = batch['age'].unsqueeze(0).unsqueeze(0).float()
    sex = batch['sex'].unsqueeze(0).unsqueeze(0).float()
    ventricle_volume = batch['ventricle_volume'].unsqueeze(0).unsqueeze(0).float()
    brain_volume = batch['brain_volume'].unsqueeze(0).unsqueeze(0).float()
    moca = batch['moca'].unsqueeze(0).unsqueeze(0).float()
    education = batch['education'].unsqueeze(0).unsqueeze(0).float()
    tau = batch['tau'].unsqueeze(0).unsqueeze(0).float()
    av45 = batch['av45'].unsqueeze(0).unsqueeze(0).float()
    apoe = batch['APOE4'].unsqueeze(0).unsqueeze(0).float()
    slice_number = batch['slice_number'].unsqueeze(0).unsqueeze(0).float()
    return {'x': x, 'age': age, 'sex': sex, 'ventricle_volume': ventricle_volume,
            'brain_volume': brain_volume, 'education': education,
            'tau': tau, 'moca': moca, 'av45': av45, 'APOE4': apoe, 'slice_number': slice_number}
experiments = ['ConditionalVISEM']
models = {}
loaded_models = {}

for exp in experiments:
    try:
        # checkpoint_path = f'{BASE_LOG_PATH}/{exp}/version_0/'
        checkpoint_path = '/home/aay993/dscm/DSCM_implementation/SVIExperiment/ConditionalVISEM/version_117'

        base_path = os.path.join(checkpoint_path, 'checkpoints')
        checkpoint_path = os.path.join(base_path, os.listdir(base_path)[0])

        ckpt = torch.load(checkpoint_path, map_location=torch.device('cpu'))
        # hparams = ckpt['hparams'] # previous function (for checkpoints already trained)
        hparams = ckpt['hyper_parameters'] # for newly trained model checkpoints 
        
        model_class = MODEL_REGISTRY[hparams['model']]

        model_params = {
            k: v for k, v in hparams.items() if (k in inspect.signature(model_class.__init__).parameters
                                                 or k in k in inspect.signature(model_class.__bases__[0].__init__).parameters
                                                 or k in k in inspect.signature(model_class.__bases__[0].__bases__[0].__init__).parameters)
        }
        
        new_state_dict = OrderedDict()

        for key, value in ckpt['state_dict'].items():
            new_key = key.replace('pyro_model.', '')
            new_state_dict[new_key] = value
            
        loaded_model = model_class(**model_params)
        loaded_model.load_state_dict(new_state_dict)
        
        for p in loaded_model._buffers.keys():
            if 'norm' in p:
                setattr(loaded_model, p, getattr(loaded_model, p))
                
        loaded_model.eval()
                
                
        loaded_models[exp] = loaded_model
        
        def sample_pgm(num_samples, model):
            with pyro.plate('observations', num_samples):
                return model.pgm_model()
        
        models[exp] = partial(sample_pgm, model=loaded_model)
    except Exception as e:
        print(e)
        traceback.print_exc()

# %%
def segment(img, k=2): 
    shape = img.shape
    img = img.reshape((-1, 1))
     # Define and run K-means 
    k_means = cluster.KMeans(n_clusters=k) 
    k_means.fit(img) 

    values = k_means.cluster_centers_.squeeze() 
    labels = k_means.labels_

    # Create an array from labels and values 
    img_data_seg = np.choose(labels, values)
    img_data_seg.shape = shape

    return len(np.argwhere(img_data_seg == np.unique(img_data_seg)[1])), img_data_seg

# %%
# Example of producing a large number of counterfactual inferences for a specific variable (age)
age_volumes_10 = [] 
age_volumes_20 = []
age_volumes_s_20 = [] 
model_name = 'ConditionalVISEM'
num_samples = 32
k = 2


for i in range(len(ukbb_test)):
    print(f'processing overall slice number {i}') 
    

    # Running counterfactuals
    orig_data = prep_data(ukbb_test[i])  


    pyro.clear_param_store()
    cond = {'age': torch.tensor([[ukbb_test[i]['age'] * 1.1]])}
    counterfactual = loaded_models[model_name].counterfactual(orig_data, cond, num_samples)
    counterfactual_img = counterfactual['x'].squeeze()

    age_volumes_10.append(segment(counterfactual_img)[0])

    pyro.clear_param_store()
    cond = {'age': torch.tensor([[ukbb_test[i]['age'] * 1.2]])}
    counterfactual = loaded_models[model_name].counterfactual(orig_data, cond, num_samples)
    counterfactual_img = counterfactual['x'].squeeze()

    age_volumes_20.append(segment(counterfactual_img)[0])

    pyro.clear_param_store()
    cond = {'age': torch.tensor([[ukbb_test[i]['age'] * 0.8]])}
    counterfactual = loaded_models[model_name].counterfactual(orig_data, cond, num_samples)
    counterfactual_img = counterfactual['x'].squeeze()

    age_volumes_s_20.append(segment(counterfactual_img)[0])
# Out:
# processing overall slice number 0
# processing overall slice number 1
# processing overall slice number 2
# processing overall slice number 3
# processing overall slice number 4
# processing overall slice number 5
# processing overall slice number 6
# processing overall slice number 7
# processing overall slice number 8
# processing overall slice number 9
# processing overall slice number 10
# processing overall slice number 11
# processing overall slice number 12
# processing overall slice number 13
# processing overall slice number 14
# processing overall slice number 15
# processing overall slice number 16
# processing overall slice number 17
# processing overall slice number 18
# processing overall slice number 19
# processing overall slice number 20
# processing overall slice number 21
# processing overall slice number 22
# processing overall slice number 23
# processing overall slice number 24
# processing overall slice number 25
# processing overall slice number 26
# processing overall slice number 27
# processing overall slice number 28
# processing overall slice number 29
# processing overall slice number 30
# processing overall slice number 31
# processing overall slice number 32
# processing overall slice number 33
# processing overall slice number 34
# processing overall slice number 35
# processing overall slice number 36
# processing overall slice number 37
# processing overall slice number 38
# processing overall slice number 39
# processing overall slice number 40
# processing overall slice number 41
# processing overall slice number 42
# processing overall slice number 43
# processing overall slice number 44
# processing overall slice number 45
# processing overall slice number 46
# processing overall slice number 47
# processing overall slice number 48
# processing overall slice number 49
# processing overall slice number 50
# processing overall slice number 51
# processing overall slice number 52
# processing overall slice number 53
# processing overall slice number 54
# processing overall slice number 55
# processing overall slice number 56
# processing overall slice number 57
# processing overall slice number 58
# processing overall slice number 59
# processing overall slice number 60
# processing overall slice number 61
# processing overall slice number 62
# processing overall slice number 63
# processing overall slice number 64
# processing overall slice number 65
# processing overall slice number 66
# processing overall slice number 67
# processing overall slice number 68
# processing overall slice number 69
# processing overall slice number 70
# processing overall slice number 71
# processing overall slice number 72
# processing overall slice number 73
# processing overall slice number 74
# processing overall slice number 75
# processing overall slice number 76
# processing overall slice number 77
# processing overall slice number 78
# processing overall slice number 79
# processing overall slice number 80
# processing overall slice number 81
# processing overall slice number 82
# processing overall slice number 83
# processing overall slice number 84
# processing overall slice number 85
# processing overall slice number 86
# processing overall slice number 87
# processing overall slice number 88
# processing overall slice number 89
# processing overall slice number 90
# processing overall slice number 91
# processing overall slice number 92
# processing overall slice number 93
# processing overall slice number 94
# processing overall slice number 95
# processing overall slice number 96
# processing overall slice number 97
# processing overall slice number 98
# processing overall slice number 99
# processing overall slice number 100
# processing overall slice number 101
# processing overall slice number 102
# processing overall slice number 103
# processing overall slice number 104
# processing overall slice number 105
# processing overall slice number 106
# processing overall slice number 107
# processing overall slice number 108
# processing overall slice number 109
# processing overall slice number 110
# processing overall slice number 111
# processing overall slice number 112
# processing overall slice number 113
# processing overall slice number 114
# processing overall slice number 115
# processing overall slice number 116
# processing overall slice number 117
# processing overall slice number 118
# processing overall slice number 119
# processing overall slice number 120
# processing overall slice number 121
# processing overall slice number 122
# processing overall slice number 123
# processing overall slice number 124
# processing overall slice number 125
# processing overall slice number 126
# processing overall slice number 127
# processing overall slice number 128
# processing overall slice number 129
# processing overall slice number 130
# processing overall slice number 131
# processing overall slice number 132
# processing overall slice number 133
# processing overall slice number 134
# processing overall slice number 135
# processing overall slice number 136
# processing overall slice number 137
# processing overall slice number 138
# processing overall slice number 139
# processing overall slice number 140
# processing overall slice number 141
# processing overall slice number 142
# processing overall slice number 143
# processing overall slice number 144
# processing overall slice number 145
# processing overall slice number 146
# processing overall slice number 147
# processing overall slice number 148
# processing overall slice number 149
# processing overall slice number 150
# processing overall slice number 151
# processing overall slice number 152
# processing overall slice number 153
# processing overall slice number 154
# processing overall slice number 155
# processing overall slice number 156
# processing overall slice number 157
# processing overall slice number 158
# processing overall slice number 159
# processing overall slice number 160
# processing overall slice number 161
# processing overall slice number 162
# processing overall slice number 163
# processing overall slice number 164
# processing overall slice number 165
# processing overall slice number 166
# processing overall slice number 167
# processing overall slice number 168
# processing overall slice number 169
# processing overall slice number 170
# processing overall slice number 171
# processing overall slice number 172
# processing overall slice number 173
# processing overall slice number 174
# processing overall slice number 175
# processing overall slice number 176
# processing overall slice number 177
# processing overall slice number 178
# processing overall slice number 179
# processing overall slice number 180
# processing overall slice number 181
# processing overall slice number 182
# processing overall slice number 183
# processing overall slice number 184
# processing overall slice number 185
# processing overall slice number 186
# processing overall slice number 187
# processing overall slice number 188
# processing overall slice number 189
# processing overall slice number 190
# processing overall slice number 191
# processing overall slice number 192
# processing overall slice number 193
# processing overall slice number 194
# processing overall slice number 195
# processing overall slice number 196
# processing overall slice number 197
# processing overall slice number 198
# processing overall slice number 199
# processing overall slice number 200
# processing overall slice number 201
# processing overall slice number 202
# processing overall slice number 203
# processing overall slice number 204
# processing overall slice number 205
# processing overall slice number 206
# processing overall slice number 207
# processing overall slice number 208
# processing overall slice number 209
# processing overall slice number 210
# processing overall slice number 211
# processing overall slice number 212
# processing overall slice number 213
# processing overall slice number 214
# processing overall slice number 215
# processing overall slice number 216
# processing overall slice number 217
# processing overall slice number 218
# processing overall slice number 219
# processing overall slice number 220
# processing overall slice number 221
# processing overall slice number 222
# processing overall slice number 223
# processing overall slice number 224
# processing overall slice number 225
# processing overall slice number 226
# processing overall slice number 227
# processing overall slice number 228
# processing overall slice number 229
# processing overall slice number 230
# processing overall slice number 231
# processing overall slice number 232
# processing overall slice number 233
# processing overall slice number 234
# processing overall slice number 235
# processing overall slice number 236
# processing overall slice number 237
# processing overall slice number 238
# processing overall slice number 239
# processing overall slice number 240
# processing overall slice number 241
# processing overall slice number 242
# processing overall slice number 243
# processing overall slice number 244
# processing overall slice number 245
# processing overall slice number 246
# processing overall slice number 247
# processing overall slice number 248
# processing overall slice number 249
# processing overall slice number 250
# processing overall slice number 251
# processing overall slice number 252
# processing overall slice number 253
# processing overall slice number 254
# processing overall slice number 255
# processing overall slice number 256
# processing overall slice number 257
# processing overall slice number 258
# processing overall slice number 259
# processing overall slice number 260
# processing overall slice number 261
# processing overall slice number 262
# processing overall slice number 263
# processing overall slice number 264
# processing overall slice number 265
# processing overall slice number 266
# processing overall slice number 267
# processing overall slice number 268
# processing overall slice number 269
# processing overall slice number 270
# processing overall slice number 271
# processing overall slice number 272
# processing overall slice number 273
# processing overall slice number 274
# processing overall slice number 275
# processing overall slice number 276
# processing overall slice number 277
# processing overall slice number 278
# processing overall slice number 279
# processing overall slice number 280
# processing overall slice number 281
# processing overall slice number 282
# processing overall slice number 283
# processing overall slice number 284
# processing overall slice number 285
# processing overall slice number 286
# processing overall slice number 287
# processing overall slice number 288
# processing overall slice number 289
# processing overall slice number 290
# processing overall slice number 291
# processing overall slice number 292
# processing overall slice number 293
# processing overall slice number 294
# processing overall slice number 295
# processing overall slice number 296
# processing overall slice number 297
# processing overall slice number 298
# processing overall slice number 299
# processing overall slice number 300
# processing overall slice number 301
# processing overall slice number 302
# processing overall slice number 303
# processing overall slice number 304
# processing overall slice number 305
# processing overall slice number 306
# processing overall slice number 307
# processing overall slice number 308
# processing overall slice number 309
# processing overall slice number 310
# processing overall slice number 311
# processing overall slice number 312
# processing overall slice number 313
# processing overall slice number 314
# processing overall slice number 315
# processing overall slice number 316
# processing overall slice number 317
# processing overall slice number 318
# processing overall slice number 319
# processing overall slice number 320
# processing overall slice number 321
# processing overall slice number 322
# processing overall slice number 323
# processing overall slice number 324
# processing overall slice number 325
# processing overall slice number 326
# processing overall slice number 327
# processing overall slice number 328
# processing overall slice number 329
# processing overall slice number 330
# processing overall slice number 331
# processing overall slice number 332
# processing overall slice number 333
# processing overall slice number 334
# processing overall slice number 335
# processing overall slice number 336
# processing overall slice number 337
# processing overall slice number 338
# processing overall slice number 339
# processing overall slice number 340
# processing overall slice number 341
# processing overall slice number 342
# processing overall slice number 343
# processing overall slice number 344
# processing overall slice number 345
# processing overall slice number 346
# processing overall slice number 347
# processing overall slice number 348
# processing overall slice number 349
# processing overall slice number 350
# processing overall slice number 351
# processing overall slice number 352
# processing overall slice number 353
# processing overall slice number 354
# processing overall slice number 355
# processing overall slice number 356
# processing overall slice number 357
# processing overall slice number 358
# processing overall slice number 359
# processing overall slice number 360
# processing overall slice number 361
# processing overall slice number 362
# processing overall slice number 363
# processing overall slice number 364
# processing overall slice number 365
# processing overall slice number 366
# processing overall slice number 367
# processing overall slice number 368
# processing overall slice number 369
# processing overall slice number 370
# processing overall slice number 371
# processing overall slice number 372
# processing overall slice number 373
# processing overall slice number 374
# processing overall slice number 375
# processing overall slice number 376
# processing overall slice number 377
# processing overall slice number 378
# processing overall slice number 379
# processing overall slice number 380
# processing overall slice number 381
# processing overall slice number 382
# processing overall slice number 383
# processing overall slice number 384
# processing overall slice number 385
# processing overall slice number 386
# processing overall slice number 387
# processing overall slice number 388
# processing overall slice number 389
# processing overall slice number 390
# processing overall slice number 391
# processing overall slice number 392
# processing overall slice number 393
# processing overall slice number 394
# processing overall slice number 395
# processing overall slice number 396
# processing overall slice number 397
# processing overall slice number 398
# processing overall slice number 399
# processing overall slice number 400
# processing overall slice number 401
# processing overall slice number 402
# processing overall slice number 403
# processing overall slice number 404
# processing overall slice number 405
# processing overall slice number 406
# processing overall slice number 407
# processing overall slice number 408
# processing overall slice number 409
# processing overall slice number 410
# processing overall slice number 411
# processing overall slice number 412
# processing overall slice number 413
# processing overall slice number 414
# processing overall slice number 415
# processing overall slice number 416
# processing overall slice number 417
# processing overall slice number 418
# processing overall slice number 419
# processing overall slice number 420
# processing overall slice number 421
# processing overall slice number 422
# processing overall slice number 423
# processing overall slice number 424
# processing overall slice number 425
# processing overall slice number 426
# processing overall slice number 427
# processing overall slice number 428
# processing overall slice number 429
# processing overall slice number 430
# processing overall slice number 431
# processing overall slice number 432
# processing overall slice number 433
# processing overall slice number 434
# processing overall slice number 435
# processing overall slice number 436
# processing overall slice number 437
# processing overall slice number 438
# processing overall slice number 439
# processing overall slice number 440
# processing overall slice number 441
# processing overall slice number 442
# processing overall slice number 443
# processing overall slice number 444
# processing overall slice number 445
# processing overall slice number 446
# processing overall slice number 447
# processing overall slice number 448
# processing overall slice number 449
# processing overall slice number 450
# processing overall slice number 451
# processing overall slice number 452
# processing overall slice number 453
# processing overall slice number 454
# processing overall slice number 455
# processing overall slice number 456
# processing overall slice number 457
# processing overall slice number 458
# processing overall slice number 459
# processing overall slice number 460
# processing overall slice number 461
# processing overall slice number 462
# processing overall slice number 463
# processing overall slice number 464
# processing overall slice number 465
# processing overall slice number 466
# processing overall slice number 467
# processing overall slice number 468
# processing overall slice number 469
# processing overall slice number 470
# processing overall slice number 471
# processing overall slice number 472
# processing overall slice number 473
# processing overall slice number 474
# processing overall slice number 475
# processing overall slice number 476
# processing overall slice number 477
# processing overall slice number 478
# processing overall slice number 479
# processing overall slice number 480
# processing overall slice number 481
# processing overall slice number 482
# processing overall slice number 483
# processing overall slice number 484
# processing overall slice number 485
# processing overall slice number 486
# processing overall slice number 487
# processing overall slice number 488
# processing overall slice number 489
# processing overall slice number 490
# processing overall slice number 491
# processing overall slice number 492
# processing overall slice number 493
# processing overall slice number 494
# processing overall slice number 495
# processing overall slice number 496
# processing overall slice number 497
# processing overall slice number 498
# processing overall slice number 499
# processing overall slice number 500
# processing overall slice number 501
# processing overall slice number 502
# processing overall slice number 503
# processing overall slice number 504
# processing overall slice number 505
# processing overall slice number 506
# processing overall slice number 507
# processing overall slice number 508
# processing overall slice number 509
# processing overall slice number 510
# processing overall slice number 511
# processing overall slice number 512
# processing overall slice number 513
# processing overall slice number 514
# processing overall slice number 515
# processing overall slice number 516
# processing overall slice number 517
# processing overall slice number 518
# processing overall slice number 519
# processing overall slice number 520
# processing overall slice number 521
# processing overall slice number 522
# processing overall slice number 523
# processing overall slice number 524
# processing overall slice number 525
# processing overall slice number 526
# processing overall slice number 527
# processing overall slice number 528
# processing overall slice number 529
# processing overall slice number 530
# processing overall slice number 531
# processing overall slice number 532
# processing overall slice number 533
# processing overall slice number 534
# processing overall slice number 535
# processing overall slice number 536
# processing overall slice number 537
# processing overall slice number 538
# processing overall slice number 539
# processing overall slice number 540
# processing overall slice number 541
# processing overall slice number 542
# processing overall slice number 543
# processing overall slice number 544
# processing overall slice number 545
# processing overall slice number 546
# processing overall slice number 547
# processing overall slice number 548
# processing overall slice number 549
# processing overall slice number 550
# processing overall slice number 551
# processing overall slice number 552
# processing overall slice number 553
# processing overall slice number 554
# processing overall slice number 555
# processing overall slice number 556
# processing overall slice number 557
# processing overall slice number 558
# processing overall slice number 559
# processing overall slice number 560
# processing overall slice number 561
# processing overall slice number 562
# processing overall slice number 563
# processing overall slice number 564
# processing overall slice number 565
# processing overall slice number 566
# processing overall slice number 567
# processing overall slice number 568
# processing overall slice number 569
# processing overall slice number 570
# processing overall slice number 571
# processing overall slice number 572
# processing overall slice number 573
# processing overall slice number 574
# processing overall slice number 575
# processing overall slice number 576
# processing overall slice number 577
# processing overall slice number 578
# processing overall slice number 579
# processing overall slice number 580
# processing overall slice number 581
# processing overall slice number 582
# processing overall slice number 583
# processing overall slice number 584
# processing overall slice number 585
# processing overall slice number 586
# processing overall slice number 587
# processing overall slice number 588
# processing overall slice number 589
# processing overall slice number 590
# processing overall slice number 591
# processing overall slice number 592
# processing overall slice number 593
# processing overall slice number 594
# processing overall slice number 595
# processing overall slice number 596
# processing overall slice number 597
# processing overall slice number 598
# processing overall slice number 599
# processing overall slice number 600
# processing overall slice number 601
# processing overall slice number 602
# processing overall slice number 603
# processing overall slice number 604
# processing overall slice number 605
# processing overall slice number 606
# processing overall slice number 607
# processing overall slice number 608
# processing overall slice number 609
# processing overall slice number 610
# processing overall slice number 611
# processing overall slice number 612
# processing overall slice number 613
# processing overall slice number 614
# processing overall slice number 615
# processing overall slice number 616
# processing overall slice number 617
# processing overall slice number 618
# processing overall slice number 619
# processing overall slice number 620
# processing overall slice number 621
# processing overall slice number 622
# processing overall slice number 623
# processing overall slice number 624
# processing overall slice number 625
# processing overall slice number 626
# processing overall slice number 627
# processing overall slice number 628
# processing overall slice number 629
# processing overall slice number 630
# processing overall slice number 631
# processing overall slice number 632
# processing overall slice number 633
# processing overall slice number 634
# processing overall slice number 635
# processing overall slice number 636
# processing overall slice number 637
# processing overall slice number 638
# processing overall slice number 639
# processing overall slice number 640
# processing overall slice number 641
# processing overall slice number 642
# processing overall slice number 643
# processing overall slice number 644
# processing overall slice number 645
# processing overall slice number 646
# processing overall slice number 647
# processing overall slice number 648
# processing overall slice number 649
# processing overall slice number 650
# processing overall slice number 651
# processing overall slice number 652
# processing overall slice number 653
# processing overall slice number 654
# processing overall slice number 655
# processing overall slice number 656
# processing overall slice number 657
# processing overall slice number 658
# processing overall slice number 659
# processing overall slice number 660
# processing overall slice number 661
# processing overall slice number 662
# processing overall slice number 663
# processing overall slice number 664
# processing overall slice number 665
# processing overall slice number 666
# processing overall slice number 667
# processing overall slice number 668
# processing overall slice number 669
# processing overall slice number 670
# processing overall slice number 671
# processing overall slice number 672
# processing overall slice number 673
# processing overall slice number 674
# processing overall slice number 675
# processing overall slice number 676
# processing overall slice number 677
# processing overall slice number 678
# processing overall slice number 679
# processing overall slice number 680
# processing overall slice number 681
# processing overall slice number 682
# processing overall slice number 683
# processing overall slice number 684
# processing overall slice number 685
# processing overall slice number 686
# processing overall slice number 687
# processing overall slice number 688
# processing overall slice number 689
# processing overall slice number 690
# processing overall slice number 691
# processing overall slice number 692
# processing overall slice number 693
# processing overall slice number 694
# processing overall slice number 695
# processing overall slice number 696
# processing overall slice number 697
# processing overall slice number 698
# processing overall slice number 699
# processing overall slice number 700
# processing overall slice number 701
# processing overall slice number 702
# processing overall slice number 703
# processing overall slice number 704
# processing overall slice number 705
# processing overall slice number 706
# processing overall slice number 707
# processing overall slice number 708
# processing overall slice number 709
# processing overall slice number 710
# processing overall slice number 711
# processing overall slice number 712
# processing overall slice number 713
# processing overall slice number 714
# processing overall slice number 715
# processing overall slice number 716
# processing overall slice number 717
# processing overall slice number 718
# processing overall slice number 719
# processing overall slice number 720
# processing overall slice number 721
# processing overall slice number 722
# processing overall slice number 723
# processing overall slice number 724
# processing overall slice number 725
# processing overall slice number 726
# processing overall slice number 727
# processing overall slice number 728
# processing overall slice number 729
# processing overall slice number 730
# processing overall slice number 731
# processing overall slice number 732
# processing overall slice number 733
# processing overall slice number 734
# processing overall slice number 735
# processing overall slice number 736
# processing overall slice number 737
# processing overall slice number 738
# processing overall slice number 739
# processing overall slice number 740
# processing overall slice number 741
# processing overall slice number 742
# processing overall slice number 743
# processing overall slice number 744
# processing overall slice number 745
# processing overall slice number 746
# processing overall slice number 747
# processing overall slice number 748
# processing overall slice number 749
# processing overall slice number 750
# processing overall slice number 751
# processing overall slice number 752
# processing overall slice number 753
# processing overall slice number 754
# processing overall slice number 755
# processing overall slice number 756
# processing overall slice number 757
# processing overall slice number 758
# processing overall slice number 759
# processing overall slice number 760
# processing overall slice number 761
# processing overall slice number 762
# processing overall slice number 763
# processing overall slice number 764
# processing overall slice number 765
# processing overall slice number 766
# processing overall slice number 767
# processing overall slice number 768
# processing overall slice number 769
# processing overall slice number 770
# processing overall slice number 771
# processing overall slice number 772
# processing overall slice number 773
# processing overall slice number 774
# processing overall slice number 775
# processing overall slice number 776
# processing overall slice number 777
# processing overall slice number 778
# processing overall slice number 779
# processing overall slice number 780
# processing overall slice number 781
# processing overall slice number 782
# processing overall slice number 783
# processing overall slice number 784
# processing overall slice number 785
# processing overall slice number 786
# processing overall slice number 787
# processing overall slice number 788
# processing overall slice number 789
# processing overall slice number 790
# processing overall slice number 791
# processing overall slice number 792
# processing overall slice number 793
# processing overall slice number 794
# processing overall slice number 795
# processing overall slice number 796
# processing overall slice number 797
# processing overall slice number 798
# processing overall slice number 799
# processing overall slice number 800
# processing overall slice number 801
# processing overall slice number 802
# processing overall slice number 803
# processing overall slice number 804
# processing overall slice number 805
# processing overall slice number 806
# processing overall slice number 807
# processing overall slice number 808
# processing overall slice number 809
# processing overall slice number 810
# processing overall slice number 811
# processing overall slice number 812
# processing overall slice number 813
# processing overall slice number 814
# processing overall slice number 815
# processing overall slice number 816
# processing overall slice number 817
# processing overall slice number 818
# processing overall slice number 819
# processing overall slice number 820
# processing overall slice number 821
# processing overall slice number 822
# processing overall slice number 823
# processing overall slice number 824
# processing overall slice number 825
# processing overall slice number 826
# processing overall slice number 827
# processing overall slice number 828
# processing overall slice number 829
# processing overall slice number 830
# processing overall slice number 831
# processing overall slice number 832
# processing overall slice number 833
# processing overall slice number 834
# processing overall slice number 835
# processing overall slice number 836
# processing overall slice number 837
# processing overall slice number 838
# processing overall slice number 839
# processing overall slice number 840
# processing overall slice number 841
# processing overall slice number 842
# processing overall slice number 843
# processing overall slice number 844
# processing overall slice number 845
# processing overall slice number 846
# processing overall slice number 847
# processing overall slice number 848
# processing overall slice number 849
# processing overall slice number 850
# processing overall slice number 851
# processing overall slice number 852
# processing overall slice number 853
# processing overall slice number 854
# processing overall slice number 855
# processing overall slice number 856
# processing overall slice number 857
# processing overall slice number 858
# processing overall slice number 859
# processing overall slice number 860
# processing overall slice number 861
# processing overall slice number 862
# processing overall slice number 863
# processing overall slice number 864
# processing overall slice number 865
# processing overall slice number 866
# processing overall slice number 867
# processing overall slice number 868
# processing overall slice number 869
# processing overall slice number 870
# processing overall slice number 871
# processing overall slice number 872
# processing overall slice number 873
# processing overall slice number 874
# processing overall slice number 875
# processing overall slice number 876
# processing overall slice number 877
# processing overall slice number 878
# processing overall slice number 879
# processing overall slice number 880
# processing overall slice number 881
# processing overall slice number 882
# processing overall slice number 883
# processing overall slice number 884
# processing overall slice number 885
# processing overall slice number 886
# processing overall slice number 887
# processing overall slice number 888
# processing overall slice number 889
# processing overall slice number 890
# processing overall slice number 891
# processing overall slice number 892
# processing overall slice number 893
# processing overall slice number 894
# processing overall slice number 895
# processing overall slice number 896
# processing overall slice number 897
# processing overall slice number 898
# processing overall slice number 899
# processing overall slice number 900
# processing overall slice number 901
# processing overall slice number 902
# processing overall slice number 903
# processing overall slice number 904
# processing overall slice number 905
# processing overall slice number 906
# processing overall slice number 907
# processing overall slice number 908
# processing overall slice number 909
# processing overall slice number 910
# processing overall slice number 911
# processing overall slice number 912
# processing overall slice number 913
# processing overall slice number 914
# processing overall slice number 915
# processing overall slice number 916
# processing overall slice number 917
# processing overall slice number 918
# processing overall slice number 919
# processing overall slice number 920
# processing overall slice number 921
# processing overall slice number 922
# processing overall slice number 923
# processing overall slice number 924
# processing overall slice number 925
# processing overall slice number 926
# processing overall slice number 927
# processing overall slice number 928
# processing overall slice number 929
# processing overall slice number 930
# processing overall slice number 931
# processing overall slice number 932
# processing overall slice number 933
# processing overall slice number 934
# processing overall slice number 935
# processing overall slice number 936
# processing overall slice number 937
# processing overall slice number 938
# processing overall slice number 939
# processing overall slice number 940
# processing overall slice number 941
# processing overall slice number 942
# processing overall slice number 943
# processing overall slice number 944
# processing overall slice number 945
# processing overall slice number 946
# processing overall slice number 947
# processing overall slice number 948
# processing overall slice number 949
# processing overall slice number 950
# processing overall slice number 951
# processing overall slice number 952
# processing overall slice number 953
# processing overall slice number 954
# processing overall slice number 955
# processing overall slice number 956
# processing overall slice number 957
# processing overall slice number 958
# processing overall slice number 959
# processing overall slice number 960
# processing overall slice number 961
# processing overall slice number 962
# processing overall slice number 963
# processing overall slice number 964
# processing overall slice number 965
# processing overall slice number 966
# processing overall slice number 967
# processing overall slice number 968
# processing overall slice number 969
# processing overall slice number 970
# processing overall slice number 971
# processing overall slice number 972
# processing overall slice number 973
# processing overall slice number 974
# processing overall slice number 975
# processing overall slice number 976
# processing overall slice number 977
# processing overall slice number 978
# processing overall slice number 979
# processing overall slice number 980
# processing overall slice number 981
# processing overall slice number 982
# processing overall slice number 983
# processing overall slice number 984
# processing overall slice number 985
# processing overall slice number 986
# processing overall slice number 987
# processing overall slice number 988
# processing overall slice number 989
# processing overall slice number 990
# processing overall slice number 991
# processing overall slice number 992
# processing overall slice number 993
# processing overall slice number 994
# processing overall slice number 995
# processing overall slice number 996
# processing overall slice number 997
# processing overall slice number 998
# processing overall slice number 999
# processing overall slice number 1000
# processing overall slice number 1001
# processing overall slice number 1002
# processing overall slice number 1003
# processing overall slice number 1004
# processing overall slice number 1005
# processing overall slice number 1006
# processing overall slice number 1007
# processing overall slice number 1008
# processing overall slice number 1009
# processing overall slice number 1010
# processing overall slice number 1011
# processing overall slice number 1012
# processing overall slice number 1013
# processing overall slice number 1014
# processing overall slice number 1015
# processing overall slice number 1016
# processing overall slice number 1017
# processing overall slice number 1018
# processing overall slice number 1019
# processing overall slice number 1020
# processing overall slice number 1021
# processing overall slice number 1022
# processing overall slice number 1023
# processing overall slice number 1024
# processing overall slice number 1025
# processing overall slice number 1026
# processing overall slice number 1027
# processing overall slice number 1028
# processing overall slice number 1029
# processing overall slice number 1030
# processing overall slice number 1031
# processing overall slice number 1032
# processing overall slice number 1033
# processing overall slice number 1034
# processing overall slice number 1035
# processing overall slice number 1036
# processing overall slice number 1037
# processing overall slice number 1038
# processing overall slice number 1039
# processing overall slice number 1040
# processing overall slice number 1041
# processing overall slice number 1042
# processing overall slice number 1043
# processing overall slice number 1044
# processing overall slice number 1045
# processing overall slice number 1046
# processing overall slice number 1047
# processing overall slice number 1048
# processing overall slice number 1049
# processing overall slice number 1050
# processing overall slice number 1051
# processing overall slice number 1052
# processing overall slice number 1053
# processing overall slice number 1054
# processing overall slice number 1055
# processing overall slice number 1056
# processing overall slice number 1057
# processing overall slice number 1058
# processing overall slice number 1059
# processing overall slice number 1060
# processing overall slice number 1061
# processing overall slice number 1062
# processing overall slice number 1063
# processing overall slice number 1064
# processing overall slice number 1065
# processing overall slice number 1066
# processing overall slice number 1067
# processing overall slice number 1068
# processing overall slice number 1069
# processing overall slice number 1070
# processing overall slice number 1071
# processing overall slice number 1072
# processing overall slice number 1073
# processing overall slice number 1074
# processing overall slice number 1075
# processing overall slice number 1076
# processing overall slice number 1077
# processing overall slice number 1078
# processing overall slice number 1079
# processing overall slice number 1080
# processing overall slice number 1081
# processing overall slice number 1082
# processing overall slice number 1083
# processing overall slice number 1084
# processing overall slice number 1085
# processing overall slice number 1086
# processing overall slice number 1087
# processing overall slice number 1088
# processing overall slice number 1089
# processing overall slice number 1090
# processing overall slice number 1091
# processing overall slice number 1092
# processing overall slice number 1093
# processing overall slice number 1094
# processing overall slice number 1095
# processing overall slice number 1096
# processing overall slice number 1097
# processing overall slice number 1098
# processing overall slice number 1099
# processing overall slice number 1100
# processing overall slice number 1101
# processing overall slice number 1102
# processing overall slice number 1103
# processing overall slice number 1104
# processing overall slice number 1105
# processing overall slice number 1106
# processing overall slice number 1107
# processing overall slice number 1108
# processing overall slice number 1109
# processing overall slice number 1110
# processing overall slice number 1111
# processing overall slice number 1112
# processing overall slice number 1113
# processing overall slice number 1114
# processing overall slice number 1115
# processing overall slice number 1116
# processing overall slice number 1117
# processing overall slice number 1118
# processing overall slice number 1119
# processing overall slice number 1120
# processing overall slice number 1121
# processing overall slice number 1122
# processing overall slice number 1123
# processing overall slice number 1124
# processing overall slice number 1125
# processing overall slice number 1126
# processing overall slice number 1127
# processing overall slice number 1128
# processing overall slice number 1129
# processing overall slice number 1130
# processing overall slice number 1131
# processing overall slice number 1132
# processing overall slice number 1133
# processing overall slice number 1134
# processing overall slice number 1135
# processing overall slice number 1136
# processing overall slice number 1137
# processing overall slice number 1138
# processing overall slice number 1139
# processing overall slice number 1140
# processing overall slice number 1141
# processing overall slice number 1142
# processing overall slice number 1143
# processing overall slice number 1144
# processing overall slice number 1145
# processing overall slice number 1146
# processing overall slice number 1147
# processing overall slice number 1148
# processing overall slice number 1149
# processing overall slice number 1150
# processing overall slice number 1151
# processing overall slice number 1152
# processing overall slice number 1153
# processing overall slice number 1154
# processing overall slice number 1155
# processing overall slice number 1156
# processing overall slice number 1157
# processing overall slice number 1158
# processing overall slice number 1159
# processing overall slice number 1160
# processing overall slice number 1161
# processing overall slice number 1162
# processing overall slice number 1163
# processing overall slice number 1164
# processing overall slice number 1165
# processing overall slice number 1166
# processing overall slice number 1167
# processing overall slice number 1168
# processing overall slice number 1169
# processing overall slice number 1170
# processing overall slice number 1171
# processing overall slice number 1172
# processing overall slice number 1173
# processing overall slice number 1174
# processing overall slice number 1175
# processing overall slice number 1176
# processing overall slice number 1177
# processing overall slice number 1178
# processing overall slice number 1179
# processing overall slice number 1180
# processing overall slice number 1181
# processing overall slice number 1182
# processing overall slice number 1183
# processing overall slice number 1184
# processing overall slice number 1185
# processing overall slice number 1186
# processing overall slice number 1187
# processing overall slice number 1188
# processing overall slice number 1189
# processing overall slice number 1190
# processing overall slice number 1191
# processing overall slice number 1192
# processing overall slice number 1193
# processing overall slice number 1194
# processing overall slice number 1195
# processing overall slice number 1196
# processing overall slice number 1197
# processing overall slice number 1198
# processing overall slice number 1199
# processing overall slice number 1200
# processing overall slice number 1201
# processing overall slice number 1202
# processing overall slice number 1203
# processing overall slice number 1204
# processing overall slice number 1205
# processing overall slice number 1206
# processing overall slice number 1207
# processing overall slice number 1208
# processing overall slice number 1209
# processing overall slice number 1210
# processing overall slice number 1211
# processing overall slice number 1212
# processing overall slice number 1213
# processing overall slice number 1214
# processing overall slice number 1215
# processing overall slice number 1216
# processing overall slice number 1217
# processing overall slice number 1218
# processing overall slice number 1219
# processing overall slice number 1220
# processing overall slice number 1221
# processing overall slice number 1222
# processing overall slice number 1223
# processing overall slice number 1224
# processing overall slice number 1225
# processing overall slice number 1226
# processing overall slice number 1227
# processing overall slice number 1228
# processing overall slice number 1229
# processing overall slice number 1230
# processing overall slice number 1231
# processing overall slice number 1232
# processing overall slice number 1233
# processing overall slice number 1234
# processing overall slice number 1235
# processing overall slice number 1236
# processing overall slice number 1237
# processing overall slice number 1238
# processing overall slice number 1239
# processing overall slice number 1240
# processing overall slice number 1241
# processing overall slice number 1242
# processing overall slice number 1243
# processing overall slice number 1244
# processing overall slice number 1245
# processing overall slice number 1246
# processing overall slice number 1247
# processing overall slice number 1248
# processing overall slice number 1249
# processing overall slice number 1250
# processing overall slice number 1251
# processing overall slice number 1252
# processing overall slice number 1253
# processing overall slice number 1254
# processing overall slice number 1255
# processing overall slice number 1256
# processing overall slice number 1257
# processing overall slice number 1258
# processing overall slice number 1259
# processing overall slice number 1260
# processing overall slice number 1261
# processing overall slice number 1262
# processing overall slice number 1263
# processing overall slice number 1264
# processing overall slice number 1265
# processing overall slice number 1266
# processing overall slice number 1267
# processing overall slice number 1268
# processing overall slice number 1269
# processing overall slice number 1270
# processing overall slice number 1271
# processing overall slice number 1272
# processing overall slice number 1273
# processing overall slice number 1274
# processing overall slice number 1275
# processing overall slice number 1276
# processing overall slice number 1277
# processing overall slice number 1278
# processing overall slice number 1279
# processing overall slice number 1280
# processing overall slice number 1281
# processing overall slice number 1282
# processing overall slice number 1283
# processing overall slice number 1284
# processing overall slice number 1285
# processing overall slice number 1286
# processing overall slice number 1287
# processing overall slice number 1288
# processing overall slice number 1289
# processing overall slice number 1290
# processing overall slice number 1291
# processing overall slice number 1292
# processing overall slice number 1293
# processing overall slice number 1294
# processing overall slice number 1295
# processing overall slice number 1296
# processing overall slice number 1297
# processing overall slice number 1298
# processing overall slice number 1299
# processing overall slice number 1300
# processing overall slice number 1301
# processing overall slice number 1302
# processing overall slice number 1303
# processing overall slice number 1304
# processing overall slice number 1305
# processing overall slice number 1306
# processing overall slice number 1307
# processing overall slice number 1308
# processing overall slice number 1309
# processing overall slice number 1310
# processing overall slice number 1311
# processing overall slice number 1312
# processing overall slice number 1313
# processing overall slice number 1314
# processing overall slice number 1315
# processing overall slice number 1316
# processing overall slice number 1317
# processing overall slice number 1318
# processing overall slice number 1319
# processing overall slice number 1320
# processing overall slice number 1321
# processing overall slice number 1322
# processing overall slice number 1323
# processing overall slice number 1324
# processing overall slice number 1325
# processing overall slice number 1326
# ...
# processing overall slice number 2218
# processing overall slice number 2219
# processing overall slice number 2220
# processing overall slice number 2221
# processing overall slice number 2222
# processing overall slice number 2223
# processing overall slice number 2224
# processing overall slice number 2225
# processing overall slice number 2226
# processing overall slice number 2227
# processing overall slice number 2228
# processing overall slice number 2229
# processing overall slice number 2230
# processing overall slice number 2231
# processing overall slice number 2232
# processing overall slice number 2233
# processing overall slice number 2234
# processing overall slice number 2235
# processing overall slice number 2236
# processing overall slice number 2237
# processing overall slice number 2238
# processing overall slice number 2239
# processing overall slice number 2240
# processing overall slice number 2241
# processing overall slice number 2242
# processing overall slice number 2243
# processing overall slice number 2244
# processing overall slice number 2245
# processing overall slice number 2246
# processing overall slice number 2247
# processing overall slice number 2248
# processing overall slice number 2249
# processing overall slice number 2250
# processing overall slice number 2251
# processing overall slice number 2252
# processing overall slice number 2253
# processing overall slice number 2254
# processing overall slice number 2255
# processing overall slice number 2256
# processing overall slice number 2257
# processing overall slice number 2258
# processing overall slice number 2259
# processing overall slice number 2260
# processing overall slice number 2261
# processing overall slice number 2262
# processing overall slice number 2263
# processing overall slice number 2264
# processing overall slice number 2265
# processing overall slice number 2266
# processing overall slice number 2267
# processing overall slice number 2268
# processing overall slice number 2269
# processing overall slice number 2270
# processing overall slice number 2271
# processing overall slice number 2272
# processing overall slice number 2273
# processing overall slice number 2274
# processing overall slice number 2275
# processing overall slice number 2276
# processing overall slice number 2277
# processing overall slice number 2278
# processing overall slice number 2279
# processing overall slice number 2280
# processing overall slice number 2281
# processing overall slice number 2282
# processing overall slice number 2283
# processing overall slice number 2284
# processing overall slice number 2285
# processing overall slice number 2286
# processing overall slice number 2287
# processing overall slice number 2288
# processing overall slice number 2289
# processing overall slice number 2290
# processing overall slice number 2291
# processing overall slice number 2292
# processing overall slice number 2293
# processing overall slice number 2294
# processing overall slice number 2295
# processing overall slice number 2296
# processing overall slice number 2297
# processing overall slice number 2298
# processing overall slice number 2299
# processing overall slice number 2300
# processing overall slice number 2301
# processing overall slice number 2302
# processing overall slice number 2303
# processing overall slice number 2304
# processing overall slice number 2305
# processing overall slice number 2306
# processing overall slice number 2307
# processing overall slice number 2308
# processing overall slice number 2309
# processing overall slice number 2310
# processing overall slice number 2311
# processing overall slice number 2312
# processing overall slice number 2313
# processing overall slice number 2314
# processing overall slice number 2315
# processing overall slice number 2316
# processing overall slice number 2317
# processing overall slice number 2318
# processing overall slice number 2319
# processing overall slice number 2320
# processing overall slice number 2321
# processing overall slice number 2322
# processing overall slice number 2323
# processing overall slice number 2324
# processing overall slice number 2325
# processing overall slice number 2326
# processing overall slice number 2327
# processing overall slice number 2328
# processing overall slice number 2329
# processing overall slice number 2330
# processing overall slice number 2331
# processing overall slice number 2332
# processing overall slice number 2333
# processing overall slice number 2334
# processing overall slice number 2335
# processing overall slice number 2336
# processing overall slice number 2337
# processing overall slice number 2338
# processing overall slice number 2339
# processing overall slice number 2340
# processing overall slice number 2341
# processing overall slice number 2342
# processing overall slice number 2343
# processing overall slice number 2344
# processing overall slice number 2345
# processing overall slice number 2346
# processing overall slice number 2347
# processing overall slice number 2348
# processing overall slice number 2349
# processing overall slice number 2350
# processing overall slice number 2351
# processing overall slice number 2352
# processing overall slice number 2353
# processing overall slice number 2354
# processing overall slice number 2355
# processing overall slice number 2356
# processing overall slice number 2357
# processing overall slice number 2358
# processing overall slice number 2359
# processing overall slice number 2360
# processing overall slice number 2361
# processing overall slice number 2362
# processing overall slice number 2363
# processing overall slice number 2364
# processing overall slice number 2365
# processing overall slice number 2366
# processing overall slice number 2367
# processing overall slice number 2368
# processing overall slice number 2369
# processing overall slice number 2370
# processing overall slice number 2371
# processing overall slice number 2372
# processing overall slice number 2373
# processing overall slice number 2374
# processing overall slice number 2375
# processing overall slice number 2376
# processing overall slice number 2377
# processing overall slice number 2378
# processing overall slice number 2379
# processing overall slice number 2380
# processing overall slice number 2381
# processing overall slice number 2382
# processing overall slice number 2383
# processing overall slice number 2384
# processing overall slice number 2385
# processing overall slice number 2386
# processing overall slice number 2387
# processing overall slice number 2388
# processing overall slice number 2389
# processing overall slice number 2390
# processing overall slice number 2391
# processing overall slice number 2392
# processing overall slice number 2393
# processing overall slice number 2394
# processing overall slice number 2395
# processing overall slice number 2396
# processing overall slice number 2397
# processing overall slice number 2398
# processing overall slice number 2399
# processing overall slice number 2400
# processing overall slice number 2401
# processing overall slice number 2402
# processing overall slice number 2403
# processing overall slice number 2404
# processing overall slice number 2405
# processing overall slice number 2406
# processing overall slice number 2407
# processing overall slice number 2408
# processing overall slice number 2409
# processing overall slice number 2410
# processing overall slice number 2411
# processing overall slice number 2412
# processing overall slice number 2413
# processing overall slice number 2414
# processing overall slice number 2415
# processing overall slice number 2416
# processing overall slice number 2417
# processing overall slice number 2418
# processing overall slice number 2419
# processing overall slice number 2420
# processing overall slice number 2421
# processing overall slice number 2422
# processing overall slice number 2423
# processing overall slice number 2424
# processing overall slice number 2425
# processing overall slice number 2426
# processing overall slice number 2427
# processing overall slice number 2428
# processing overall slice number 2429
# processing overall slice number 2430
# processing overall slice number 2431
# processing overall slice number 2432
# processing overall slice number 2433
# processing overall slice number 2434
# processing overall slice number 2435
# processing overall slice number 2436
# processing overall slice number 2437
# processing overall slice number 2438
# processing overall slice number 2439
# processing overall slice number 2440
# processing overall slice number 2441
# processing overall slice number 2442
# processing overall slice number 2443
# processing overall slice number 2444
# processing overall slice number 2445
# processing overall slice number 2446
# processing overall slice number 2447
# processing overall slice number 2448
# processing overall slice number 2449
# processing overall slice number 2450
# processing overall slice number 2451
# processing overall slice number 2452
# processing overall slice number 2453
# processing overall slice number 2454
# processing overall slice number 2455
# processing overall slice number 2456
# processing overall slice number 2457
# processing overall slice number 2458
# processing overall slice number 2459
# processing overall slice number 2460
# processing overall slice number 2461
# processing overall slice number 2462
# processing overall slice number 2463
# processing overall slice number 2464
# processing overall slice number 2465
# processing overall slice number 2466
# processing overall slice number 2467
# processing overall slice number 2468
# processing overall slice number 2469
# processing overall slice number 2470
# processing overall slice number 2471
# processing overall slice number 2472
# processing overall slice number 2473
# processing overall slice number 2474
# processing overall slice number 2475
# processing overall slice number 2476
# processing overall slice number 2477
# processing overall slice number 2478
# processing overall slice number 2479
# processing overall slice number 2480
# processing overall slice number 2481
# processing overall slice number 2482
# processing overall slice number 2483
# processing overall slice number 2484
# processing overall slice number 2485
# processing overall slice number 2486
# processing overall slice number 2487
# processing overall slice number 2488
# processing overall slice number 2489
# processing overall slice number 2490
# processing overall slice number 2491
# processing overall slice number 2492
# processing overall slice number 2493
# processing overall slice number 2494
# processing overall slice number 2495
# processing overall slice number 2496
# processing overall slice number 2497
# processing overall slice number 2498
# processing overall slice number 2499
# processing overall slice number 2500
# processing overall slice number 2501
# processing overall slice number 2502
# processing overall slice number 2503
# processing overall slice number 2504
# processing overall slice number 2505
# processing overall slice number 2506
# processing overall slice number 2507
# processing overall slice number 2508
# processing overall slice number 2509
# processing overall slice number 2510
# processing overall slice number 2511
# processing overall slice number 2512
# processing overall slice number 2513
# processing overall slice number 2514
# processing overall slice number 2515
# processing overall slice number 2516
# processing overall slice number 2517
# processing overall slice number 2518
# processing overall slice number 2519
# processing overall slice number 2520
# processing overall slice number 2521
# processing overall slice number 2522
# processing overall slice number 2523
# processing overall slice number 2524
# processing overall slice number 2525
# processing overall slice number 2526
# processing overall slice number 2527
# processing overall slice number 2528
# processing overall slice number 2529
# processing overall slice number 2530
# processing overall slice number 2531
# processing overall slice number 2532
# processing overall slice number 2533
# processing overall slice number 2534
# processing overall slice number 2535
# processing overall slice number 2536
# processing overall slice number 2537
# processing overall slice number 2538
# processing overall slice number 2539
# processing overall slice number 2540
# processing overall slice number 2541
# processing overall slice number 2542
# processing overall slice number 2543
# processing overall slice number 2544
# processing overall slice number 2545
# processing overall slice number 2546
# processing overall slice number 2547
# processing overall slice number 2548
# processing overall slice number 2549
# processing overall slice number 2550
# processing overall slice number 2551
# processing overall slice number 2552
# processing overall slice number 2553
# processing overall slice number 2554
# processing overall slice number 2555
# processing overall slice number 2556
# processing overall slice number 2557
# processing overall slice number 2558
# processing overall slice number 2559
# processing overall slice number 2560
# processing overall slice number 2561
# processing overall slice number 2562
# processing overall slice number 2563
# processing overall slice number 2564
# processing overall slice number 2565
# processing overall slice number 2566
# processing overall slice number 2567
# processing overall slice number 2568
# processing overall slice number 2569
# processing overall slice number 2570
# processing overall slice number 2571
# processing overall slice number 2572
# processing overall slice number 2573
# processing overall slice number 2574
# processing overall slice number 2575
# processing overall slice number 2576
# processing overall slice number 2577
# processing overall slice number 2578
# processing overall slice number 2579
# processing overall slice number 2580
# processing overall slice number 2581
# processing overall slice number 2582
# processing overall slice number 2583
# processing overall slice number 2584
# processing overall slice number 2585
# processing overall slice number 2586
# processing overall slice number 2587
# processing overall slice number 2588
# processing overall slice number 2589
# processing overall slice number 2590
# processing overall slice number 2591
# processing overall slice number 2592
# processing overall slice number 2593
# processing overall slice number 2594
# processing overall slice number 2595
# processing overall slice number 2596
# processing overall slice number 2597
# processing overall slice number 2598
# processing overall slice number 2599
# processing overall slice number 2600
# processing overall slice number 2601
# processing overall slice number 2602
# processing overall slice number 2603
# processing overall slice number 2604
# processing overall slice number 2605
# processing overall slice number 2606
# processing overall slice number 2607
# processing overall slice number 2608
# processing overall slice number 2609
# processing overall slice number 2610
# processing overall slice number 2611
# processing overall slice number 2612
# processing overall slice number 2613
# processing overall slice number 2614
# processing overall slice number 2615
# processing overall slice number 2616
# processing overall slice number 2617
# processing overall slice number 2618
# processing overall slice number 2619
# processing overall slice number 2620
# processing overall slice number 2621
# processing overall slice number 2622
# processing overall slice number 2623
# processing overall slice number 2624
# processing overall slice number 2625
# processing overall slice number 2626
# processing overall slice number 2627
# processing overall slice number 2628
# processing overall slice number 2629
# processing overall slice number 2630
# processing overall slice number 2631
# processing overall slice number 2632
# processing overall slice number 2633
# processing overall slice number 2634
# processing overall slice number 2635
# processing overall slice number 2636
# processing overall slice number 2637
# processing overall slice number 2638
# processing overall slice number 2639
# processing overall slice number 2640
# processing overall slice number 2641
# processing overall slice number 2642
# processing overall slice number 2643
# processing overall slice number 2644
# processing overall slice number 2645
# processing overall slice number 2646
# processing overall slice number 2647
# processing overall slice number 2648
# processing overall slice number 2649

# %%
df_age = pd.DataFrame(data=list(zip(age_volumes_10, age_volumes_20, age_volumes_s_20)), columns=['+10%', '+20%', '-20%'])
df_age
# Out:
#       +10%  +20%  -20%
# 0     1714  1669  1728
# 1     1757  1727  1776
# 2     1753  1711  1760
# 3     1692  1671  1714
# 4     1626  1617  1644
# ...    ...   ...   ...
# 2645  1450  1454  1510
# 2646  1422  1405  1464
# 2647  1402  1403  1438
# 2648  1392  1390  1429
# 2649  1363  1360  1418
#
# [2650 rows x 3 columns]

# %%
df_age['Original masks'] = df['Original masks']
df_age
# Out:
#       +10%  +20%  -20%  Original masks
# 0     1714  1669  1728            1738
# 1     1757  1727  1776            1776
# 2     1753  1711  1760            1762
# 3     1692  1671  1714            1717
# 4     1626  1617  1644            1645
# ...    ...   ...   ...             ...
# 2645  1450  1454  1510            1458
# 2646  1422  1405  1464            1433
# 2647  1402  1403  1438            1403
# 2648  1392  1390  1429            1398
# 2649  1363  1360  1418            1378
#
# [2650 rows x 4 columns]

# %%
df_age.to_csv('age_brain_volume_seg_validations.csv')

# %%
idx = 3
original_image = imread(f'original_{idx}.png')
counterfactual_image = imread(f'counterfactual_{idx}.png')


def segmentation_plot(imgs, num_clusters, img_title, save=False): 
 
    np.random.seed(0) 

    # segmentations 
    segmentations = {}

    for i in range(len(imgs)):
        # Reshape to a (n_sample, n_feature) array 
        X = imgs[i].reshape((-1, 1))

        # Define an run K-means
        k = num_clusters 
        k_means = cluster.KMeans(n_clusters=k)
        k_means.fit(X)

        values = k_means.cluster_centers_.squeeze()
        labels = k_means.labels_

        # Create an array from labels and values 
        segmentations[f'img_data_seg_{i}_{k}'] = np.choose(labels, values)
        segmentations[f'img_data_seg_{i}_{k}'].shape = imgs[0].shape
        # img_data_seg = np.choose(labels, values)
        # img_data_seg.shape = img.shape 
    

    vmin = imgs[0].min()
    vmax = imgs[0].max() 

    plt.figure(figsize=(15, 7))
    cmaps = ['Blues', 'Oranges']
    alphas = [.8, .4]
    ticker = 1

    for i in range(len(imgs)): 
        

        plt.subplot(len(imgs), 4, ticker)
        plt.imshow(imgs[i], cmap='gray', vmin=vmin, vmax=256)
        plt.axis('off')
        plt.title(img_title[i], size=21)
        plt.tight_layout() 
        ticker += 1

    for i in range(len(imgs)):    
        k = num_clusters 
        plt.subplot(len(imgs), 4, 3)
        plt.imshow(segmentations[f'img_data_seg_{i}_{k}'], cmap=cmaps[i], vmin=vmin, vmax=vmax,  alpha=alphas[i])
        plt.title(f'Segmentation (k={k})', size=21)
        plt.axis('off')
        plt.tight_layout()
        pixels, _ = segment(segmentations[f'img_data_seg_{i}_{k}'])
        print(pixels)
        
        
    
    if save: 
        plt.savefig('segmentation_single_participant.png', dpi=600, bbox_inches='tight')
    
    return segmentations

segmentations = segmentation_plot([original_image, counterfactual_image], 2, ['Original image (980 ml)', 'Counterfactual (1600 ml)'], save=True)
# Out:
# 1284
# 1386

# %%
df = pd.read_csv('brain_volume_seg_validations.csv')
df_mean = df.groupby(np.arange(len(df))//10).mean()
sns.jointplot(x=df_mean['Original masks'], y=df_mean['FSL volumes'], kind='hex', color='#002061')
sns.regplot(x=df_mean['Original masks'], y=df_mean['FSL volumes'], color='#974700', marker='')
plt.xlabel('Segmentation mask (pixels)', size=16)
plt.ylabel('Whole brain volume (ml)', size=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=18)
plt.tight_layout()
plt.savefig('correlation_seg_mask_FSL_volume.png', dpi=600, bbox_inches='tight')

# %%
import scipy 
scipy.stats.pearsonr(df_mean['Original masks'], df_mean['FSL volumes']) # Calculate R value between the segmentation masks and the whole brain volume.
# Out:
# (0.7050497814714984, 3.8642729212832247e-41)

# %%
def calculate_percentage(df, column): 
    variable = df[f'{column}'] 
    diff = variable - df['Original masks'] 
    percentage = (diff / df['Original masks']) * 100 
    return percentage

# %%
from statannotations.Annotator import Annotator
import statsmodels


# For the statistical testing
df_real = pd.read_csv('brain_volume_seg_validations.csv')

values = np.concatenate((
    df_real['-40%'].to_numpy(), 
    df_real['Original masks'].to_numpy(),
    df_real['+40%'].to_numpy(), 
    df_real['+60%'].to_numpy()))

df_real = pd.DataFrame(data=values, columns=['values'])
df_real['interventions'] = 0
df_real['interventions'].iloc[:2650] = '-40%'
df_real['interventions'].iloc[2650:2650*2] = 'NULL'
df_real['interventions'].iloc[2650*2:2650*3] = '+40%'
df_real['interventions'].iloc[2650*3:] = '+60%' 

df_real_age = pd.read_csv('age_brain_volume_seg_validations.csv')

values = np.concatenate((
    df_real_age['-20%'].to_numpy(), 
    df_real_age['Original masks'].to_numpy(),
    df_real_age['+10%'].to_numpy(), 
    df_real_age['+20%'].to_numpy()))

df_real_age = pd.DataFrame(data=values, columns=['values'])
df_real_age['interventions'] = 0
df_real_age['interventions'].iloc[:2650] = '-20%'
df_real_age['interventions'].iloc[2650:2650*2] = 'NULL'
df_real_age['interventions'].iloc[2650*2:2650*3] = '+10%'
df_real_age['interventions'].iloc[2650*3:] = '+20%' 

df_real_av45 = pd.read_csv('av45_brain_volume_seg_validations.csv')

values = np.concatenate((
    df_real_av45['-50%'].to_numpy(), 
    df_real_av45['Original masks'].to_numpy(),
    df_real_av45['+200%'].to_numpy(), 
    df_real_av45['+700%'].to_numpy()))

df_real_av45 = pd.DataFrame(data=values, columns=['values'])
df_real_av45['interventions'] = 0
df_real_av45['interventions'].iloc[:2650] = '-50%'
df_real_av45['interventions'].iloc[2650:2650*2] = 'NULL'
df_real_av45['interventions'].iloc[2650*2:2650*3] = '+100%'
df_real_av45['interventions'].iloc[2650*3:] = '+200%'


# For the plotting of percentage change
df = pd.read_csv('brain_volume_seg_validations.csv')
df_age = pd.read_csv('age_brain_volume_seg_validations.csv')
df_av45 = pd.read_csv('av45_brain_volume_seg_validations.csv')

# Converting dataframe to format compatiable with statannotations
values = np.concatenate((
    calculate_percentage(df, '-40%').to_numpy(), 
    calculate_percentage(df, 'Original masks').to_numpy(),
    calculate_percentage(df, '+40%').to_numpy(), 
    calculate_percentage(df, '+60%').to_numpy()))

df = pd.DataFrame(data=values, columns=['values'])
df['interventions'] = 0
df['interventions'].iloc[:2650] = '-40%'
df['interventions'].iloc[2650:2650*2] = 'NULL'
df['interventions'].iloc[2650*2:2650*3] = '+40%'
df['interventions'].iloc[2650*3:] = '+60%'

plt.figure(figsize=(20, 5))

# First plot 
plt.subplot(1, 3, 1)
plt.title('Brain volume (ml)', size=20)
ax = sns.violinplot(data=df, x='interventions', y='values', palette="Pastel1") 
plt.xlabel('Atomic intervention', size=16)
plt.ylabel('Segmentation mask change (%)', size=16)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

annot = Annotator(ax, [("-40%", "NULL"), ("+40%", "NULL"), ('+60%', 'NULL')], data=df_real, x='interventions', y='values')
annot.configure(test='t-test_welch', text_format='star', loc='inside', comparisons_correction="Bonferroni", verbose=2)
annot.apply_test().annotate(line_offset_to_group=0.3, line_offset=0.1)

# Converting dataframe to format compatiable with statannotations
values = np.concatenate((
    calculate_percentage(df_age, '-20%').to_numpy(), 
    calculate_percentage(df_age, 'Original masks').to_numpy(),
    calculate_percentage(df_age, '+10%').to_numpy(), 
    calculate_percentage(df_age, '+20%').to_numpy()))

df_age = pd.DataFrame(data=values, columns=['values'])
df_age['interventions'] = 0
df_age['interventions'].iloc[:2650] = '-20%'
df_age['interventions'].iloc[2650:2650*2] = 'NULL'
df_age['interventions'].iloc[2650*2:2650*3] = '+10%'
df_age['interventions'].iloc[2650*3:] = '+20%'

# Second plot. 
plt.subplot(1, 3, 2)
plt.title('Age (years)', size=20)
ax = sns.violinplot(data=df_age, x='interventions', y='values', palette="Pastel1") 
plt.xlabel('Atomic intervention', size=16) 
plt.ylabel('')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)


annot = Annotator(ax, [("-20%", "NULL"), ("NULL", "+10%"), ('NULL', '+20%')], data=df_real_age, x='interventions', y='values')
annot.configure(test='t-test_welch', text_format='star', loc='inside', comparisons_correction="Bonferroni", verbose=2)
annot.apply_test().annotate(line_offset_to_group=0.4, line_offset=0.1)

# Converting dataframe to format compatiable with statannotations
values = np.concatenate((
    calculate_percentage(df_av45, '-50%').to_numpy(), 
    calculate_percentage(df_av45, 'Original masks').to_numpy(),
    calculate_percentage(df_av45, '+200%').to_numpy(), 
    calculate_percentage(df_av45, '+700%').to_numpy()))

df_av45 = pd.DataFrame(data=values, columns=['values'])
df_av45['interventions'] = 0
df_av45['interventions'].iloc[:2650] = '-50%'
df_av45['interventions'].iloc[2650:2650*2] = 'NULL'
df_av45['interventions'].iloc[2650*2:2650*3] ='+100%'
df_av45['interventions'].iloc[2650*3:] = '+200%'

# Third plot. 
plt.subplot(1, 3, 3)
plt.title('AV45 (mSUVR)', size=20)
ax = sns.violinplot(data=df_av45, x='interventions', y='values', palette="Pastel1", inner='box') 
plt.xlabel('Atomic intervention', size=16) 
plt.ylabel('')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

annot = Annotator(ax, [("-50%", "NULL"), ("NULL", "+100%"), ('NULL', '+200%')], data=df_real_av45, x='interventions', y='values')
annot.configure(test='t-test_welch', text_format='star', loc='inside', comparisons_correction="Bonferroni", verbose=2)
annot.apply_test().annotate(line_offset_to_group=0.8, line_offset=0.1)


plt.savefig('statistical_testing_of_counterfactuals.png', dpi=900, bbox_inches='tight')


# plt.savefig('example_non-hue_inside.png', dpi=300, bbox_inches='tight')
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# -40% vs. NULL: Welch's t-test independent samples with Bonferroni correction, P_val:7.722e-64 t=-1.717e+01
# NULL vs. +40%: Welch's t-test independent samples with Bonferroni correction, P_val:1.255e-35 t=-1.264e+01
# NULL vs. +60%: Welch's t-test independent samples with Bonferroni correction, P_val:4.482e-74 t=-1.856e+01
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# -20% vs. NULL: Welch's t-test independent samples with Bonferroni correction, P_val:8.973e-01 t=1.038e+00
# NULL vs. +10%: Welch's t-test independent samples with Bonferroni correction, P_val:4.520e-01 t=1.437e+00
# NULL vs. +20%: Welch's t-test independent samples with Bonferroni correction, P_val:5.823e-04 t=3.729e+00
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# -50% vs. NULL: Welch's t-test independent samples with Bonferroni correction, P_val:2.347e-01 t=-1.761e+00
# /home/aay993/python_envs_WSL/dscm/lib/python3.8/site-packages/pandas/core/indexing.py:1636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /home/aay993/python_envs_WSL/dscm/lib/python3.8/site-packages/pandas/core/indexing.py:1636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# NULL vs. +100%: Welch's t-test independent samples with Bonferroni correction, P_val:1.869e-07 t=5.420e+00
# NULL vs. +200%: Welch's t-test independent samples with Bonferroni correction, P_val:1.977e-25 t=1.058e+01

# %%
import collections 
from collections import namedtuple
from scipy import special

def welch_anova_np(*args, var_equal=False):
    # https://svn.r-project.org/R/trunk/src/library/stats/R/oneway.test.R
    # translated from R Welch ANOVA (not assuming equal variance)

    F_onewayResult = namedtuple('F_onewayResult', ('statistic', 'pvalue'))

    args = [np.asarray(arg, dtype=float) for arg in args]
    k = len(args)
    ni =np.array([len(arg) for arg in args])
    mi =np.array([np.mean(arg) for arg in args])
    vi =np.array([np.var(arg,ddof=1) for arg in args])
    wi = ni/vi

    tmp =sum((1-wi/sum(wi))**2 / (ni-1))
    tmp /= (k**2 -1)

    dfbn = k - 1
    dfwn = 1 / (3 * tmp)

    m = sum(mi*wi) / sum(wi)
    f = sum(wi * (mi - m)**2) /((dfbn) * (1 + 2 * (dfbn - 1) * tmp))
    prob = special.fdtrc(dfbn, dfwn, f)   # equivalent to stats.f.sf
    return F_onewayResult(f, prob)

# %%
welch_anova_np(df_age['+10%'], df_age['+20%'], df_age['-20%'])
# Out:
# F_onewayResult(statistic=11.356681403355225, pvalue=1.1978393707402552e-05)

# %%
welch_anova_np(df['-40%'], df['+40%'], df['+60%'])
# Out:
# F_onewayResult(statistic=731.0436976886334, pvalue=4.255319595023352e-281)

# %%
welch_anova_np(df_av45['-50%'], df_av45['+200%'], df_av45['+700%'])
# Out:
# F_onewayResult(statistic=38.589872695253725, pvalue=2.2994320336663158e-17)
